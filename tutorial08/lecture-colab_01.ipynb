# %% [markdown]
# # Moduly
#
# Související přednáška [zde](http://vyuka.ookami.cz/materialy/python/modules/_modules.xml), oficální dokumentace [tady](https://docs.python.org/3/tutorial/modules.html).
#
# Modul v pythonu je soubor obsahující nějaký kód (např. příkazy, funkce, třídy a další). Jméno souboru je jméno modulu + přípona `.py`.
#
# **K pojmenovávání** (viz [PEP-8](https://www.python.org/dev/peps/pep-0008/#package-and-module-names)):
#
#
# *   Pro **modul** použijte krátké jméno psané výhradně malými písmeny a podtržítkem (pokud to zlepší čitelnost).
# *   Pro **balíček** je to stejné jako pro moduly, ale podtržítkům se spíš vyhněte.
#
# Modul načteme pomocí klíčového slova `import`. Python obsahuje mnoho standardních modulů (https://docs.python.org/3/library/), pojďme si ukázat základní vlastnosti modulů na modulu `this`:

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# modul `this` je easter egg a jeho jediným posláním je vypsat The Zen of Python. Pojďme si udělat takový náš vlastní modul this, který tento text vypíše přeložený do češtiny pomocí google translatoru.
#
# Google translator pro python řeší modul `googletrans`.

# %%
# !pip install deep-translator
# Out:
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.11/dist-packages (from deep-translator) (4.13.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from deep-translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (4.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2025.1.31)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: deep-translator
# Successfully installed deep-translator-1.11.4

# %% [markdown]
# Nejprve si zobrazíme zdrojový kód modulu `this`:

# %%
import inspect
import this

print(inspect.getsource(this))
# Out:
# s = """Gur Mra bs Clguba, ol Gvz Crgref
#
# Ornhgvshy vf orggre guna htyl.
# Rkcyvpvg vf orggre guna vzcyvpvg.
# Fvzcyr vf orggre guna pbzcyrk.
# Pbzcyrk vf orggre guna pbzcyvpngrq.
# Syng vf orggre guna arfgrq.
# Fcnefr vf orggre guna qrafr.
# Ernqnovyvgl pbhagf.
# Fcrpvny pnfrf nera'g fcrpvny rabhtu gb oernx gur ehyrf.
# Nygubhtu cenpgvpnyvgl orngf chevgl.
# Reebef fubhyq arire cnff fvyragyl.
# Hayrff rkcyvpvgyl fvyraprq.
# Va gur snpr bs nzovthvgl, ershfr gur grzcgngvba gb thrff.
# Gurer fubhyq or bar-- naq cersrenoyl bayl bar --boivbhf jnl gb qb vg.
# Nygubhtu gung jnl znl abg or boivbhf ng svefg hayrff lbh'er Qhgpu.
# Abj vf orggre guna arire.
# Nygubhtu arire vf bsgra orggre guna *evtug* abj.
# Vs gur vzcyrzragngvba vf uneq gb rkcynva, vg'f n onq vqrn.
# Vs gur vzcyrzragngvba vf rnfl gb rkcynva, vg znl or n tbbq vqrn.
# Anzrfcnprf ner bar ubaxvat terng vqrn -- yrg'f qb zber bs gubfr!"""
#
# d = {}
# for c in (65, 97):
#     for i in range(26):
#         d[chr(i+c)] = chr((i+13) % 26 + c)
#
# print("".join([d.get(c, c) for c in s]))

# %% [markdown]
# Nyní vyrobíme vlastní verzi, v níž provedeme překlad pomocí Google translatoru a kód uložíme do souboru `this.py`. Povšiměte si, že pokud potřebuji naimportovat jen jeden objekt z modulu, nepoužívám `import modul` ale `from modul import objekt`.

# %%
# To samé by šlo udělat pomocí cell magic `%% writefile`, ale aspoň si zopakujeme práci se soubory:

content = inspect.getsource(this)
content = "\n".join(content.split("\n")[:-2])  # strip 2 last lines

# write new code to file
with open('./this.py', mode='wt', encoding='utf-8') as f:
  f.write('from deep_translator import GoogleTranslator\n\n')
  f.write(f'{content}\n')
  f.write('print(GoogleTranslator(source="auto", target="cs").translate("".join([d.get(c, c) for c in s])))\n\n')

# print for a check
# !cat ./this.py
# Out:
# from deep_translator import GoogleTranslator
#
# s = """Gur Mra bs Clguba, ol Gvz Crgref
#
# Ornhgvshy vf orggre guna htyl.
# Rkcyvpvg vf orggre guna vzcyvpvg.
# Fvzcyr vf orggre guna pbzcyrk.
# Pbzcyrk vf orggre guna pbzcyvpngrq.
# Syng vf orggre guna arfgrq.
# Fcnefr vf orggre guna qrafr.
# Ernqnovyvgl pbhagf.
# Fcrpvny pnfrf nera'g fcrpvny rabhtu gb oernx gur ehyrf.
# Nygubhtu cenpgvpnyvgl orngf chevgl.
# Reebef fubhyq arire cnff fvyragyl.
# Hayrff rkcyvpvgyl fvyraprq.
# Va gur snpr bs nzovthvgl, ershfr gur grzcgngvba gb thrff.
# Gurer fubhyq or bar-- naq cersrenoyl bayl bar --boivbhf jnl gb qb vg.
# Nygubhtu gung jnl znl abg or boivbhf ng svefg hayrff lbh'er Qhgpu.
# Abj vf orggre guna arire.
# Nygubhtu arire vf bsgra orggre guna *evtug* abj.
# Vs gur vzcyrzragngvba vf uneq gb rkcynva, vg'f n onq vqrn.
# Vs gur vzcyrzragngvba vf rnfl gb rkcynva, vg znl or n tbbq vqrn.
# Anzrfcnprf ner bar ubaxvat terng vqrn -- yrg'f qb zber bs gubfr!"""
#
# d = {}
# for c in (65, 97):
#     for i in range(26):
#         d[chr(i+c)] = chr((i+13) % 26 + c)
#
# print(GoogleTranslator(source="auto", target="cs").translate("".join([d.get(c, c) for c in s])))

# %% [markdown]
# Nyní nám již stačí náš nový modul `this` naimportovat.

# %%
import this  # no output printed, module is already imported

# %% [markdown]
# To ovšem není tak snadné, protože modul `this` už je naimportován a tak musíme použít funkci `reload` z modulu `importlib`:

# %%
from importlib import reload
this = reload(this)
# Out:
# Zen Pythonu, Tim Peters
#
# Krásná je lepší než ošklivá.
# Explicitní je lepší než implicitní.
# Jednoduché je lepší než složité.
# Komplex je lepší než komplikované.
# Byt je lepší než vnořený.
# Řídká je lepší než hustá.
# Počty čitelnosti.
# Zvláštní případy nejsou dostatečně zvláštní, aby porušily pravidla.
# Ačkoli praktičnost bije čistotu.
# Chyby by nikdy neměly procházet tiše.
# Pokud není výslovně umlčena.
# Tváří v tvář nejednoznačnosti odmítněte pokušení uhodnout.
# Měl by existovat jeden-a nejlépe jen jeden-zřejmý způsob, jak to udělat.
# Ačkoli tento způsob nemusí být zpočátku zřejmý, pokud nejste nizozemští.
# Nyní je lepší než nikdy.
# Ačkoli nikdy není často lepší než * správně *.
# Pokud je implementace obtížně vysvětleno, je to špatný nápad.
# Pokud je implementace snadno vysvětlitelná, může to být dobrý nápad.
# Jmenné prostory jsou jeden troubící skvělý nápad - udělejme z nich více!

# %% [markdown]
# A hned si k tomu pojďme říct několik poznámek:
#
# 1. Ačkoliv se většina myšlenek původního textu vinou google translatoru v překladu ztratila, některé nové se v překladu objevily. (Jako vždy při použití automatických překladačů)
#
# 2. Jak již bylo řečeno, soubor `this.py` je zároveň modul `this`
#
# 3. Samozřejmě si ho můžeme i spustit pomocí `python this.py`
#
# 4. ❗Existencí souboru `this.py` jsme efektivně **znemožnili importovat modul** `this` ze standardní knihovny. Na toto si prosím dávejte velký pozor a pojmenovávejte své moduly s rozvahou.
#
# 5. Pojmenování modulů je řešeno v [PEP8](https://www.python.org/dev/peps/pep-0008/#package-and-module-names): *Modules should have short, all-lowercase names. Underscores can be used in the module name if it improves readability.*
#
# 6. To, že soubor `.py` je zároveň modul znamená, že v názvu modulu nemůžou být některé znaky (například `-`, protože `-` je operátor) - viz úvod k modulům/PEP8.

# %% [markdown]
# Poznámka č. 4 vzbuzuje otázku odkud se vlastně berou soubory (moduly) k importu. Kde python hledá soubor `this.py`, když v kódu napíšeme `import this`?
#
# Nejprve začne v aktuálním pracovním adresáři (tj. tam, kde je script v němž je `import`), pak pokračuje v adresářích dále uvedených v **PYTHONPATH**. K tomu se jde dostat přes `sys.path`:

# %%
# !ls -la
import sys
sys.path
# Out:
# total 24
# drwxr-xr-x 1 root root 4096 Apr  7 10:02 .
# drwxr-xr-x 1 root root 4096 Apr  7 09:55 ..
# drwxr-xr-x 4 root root 4096 Apr  3 13:37 .config
# drwxr-xr-x 2 root root 4096 Apr  7 10:02 __pycache__
# drwxr-xr-x 1 root root 4096 Apr  3 13:37 sample_data
# -rw-r--r-- 1 root root 1106 Apr  7 10:01 this.py
# ['/content',
#  '/env/python',
#  '/usr/lib/python311.zip',
#  '/usr/lib/python3.11',
#  '/usr/lib/python3.11/lib-dynload',
#  '',
#  '/usr/local/lib/python3.11/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.11/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %% [markdown]
# soubor `this.py` nám zastínil standardní modul `this`, protože cesta k němu je v seznamu `sys.path` na prvním místě. Pokud aktuální adresář přesuneme na konec seznamu, opět bude importován standardní modul `this`.

# %%
sys.path = [*sys.path[1:], sys.path[0]]
sys.path
# Out:
# ['/env/python',
#  '/usr/lib/python311.zip',
#  '/usr/lib/python3.11',
#  '/usr/lib/python3.11/lib-dynload',
#  '',
#  '/usr/local/lib/python3.11/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.11/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content']

# %%
# teď už načteme zase výchozí modul `this`
import this
this = reload(this)
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# Nyní nám už jenom zbývá odhalit umístění originálního souboru `this.py` - je to samozřejmě jedna z cest v `sys.path`:

# %%
from pathlib import Path
import re  # regular expression matching

for p in sys.path:
  print(f'scanning dir: {p}')
  try:
    for f in Path(p).iterdir():
      # print(f)
      if re.findall(r'.*this\.py', str(f)):
        print(f'\tFOUND this.py here!')
  except:
    pass

# alternatively:
# !ls /usr/lib/python3.7
# Out:
# scanning dir: /env/python
# scanning dir: /usr/lib/python311.zip
# scanning dir: /usr/lib/python3.11
# 	FOUND this.py here!
# scanning dir: /usr/lib/python3.11/lib-dynload
# scanning dir:
# 	FOUND this.py here!
# scanning dir: /usr/local/lib/python3.11/dist-packages
# scanning dir: /usr/lib/python3/dist-packages
# scanning dir: /usr/local/lib/python3.11/dist-packages/IPython/extensions
# scanning dir: /root/.ipython
# scanning dir: /content
# 	FOUND this.py here!

# %% [markdown]
# Modul je objekt a jako takový má samozřejmě další atributy, můžete si je zobrazit pomocí `dir(objekt)` a následně prozkoumat. Já se chci zaměřit pouze na jeden atribut -  `__name__`, který obsahuje řetězec s názvem modulu. To je zajímavé, protože základní (hlavní) modul, který jsme (například) spustili z příkazové řádky má `__name__ == '__main__'`.

# %%
this.__name__
# Out:
# 'this'

# %%
print(__name__)
# Out:
# __main__

# %% [markdown]
# Toho se dá využít k ošetření chování modulu v případě, že je spuštěn z příkazové řádky:

# %%
# %%writefile this.py

if __name__ == '__main__':
  print("For import only")
  exit()

from deep_translator import (GoogleTranslator,
                             MicrosoftTranslator,
                             PonsTranslator,
                             LingueeTranslator,
                             MyMemoryTranslator,
                             YandexTranslator,
                             PapagoTranslator,
                             single_detection,
                             batch_detection)

s = """Gur Mra bs Clguba, ol Gvz Crgref

Ornhgvshy vf orggre guna htyl.
Rkcyvpvg vf orggre guna vzcyvpvg.
Fvzcyr vf orggre guna pbzcyrk.
Pbzcyrk vf orggre guna pbzcyvpngrq.
Syng vf orggre guna arfgrq.
Fcnefr vf orggre guna qrafr.
Ernqnovyvgl pbhagf.
Fcrpvny pnfrf nera'g fcrpvny rabhtu gb oernx gur ehyrf.
Nygubhtu cenpgvpnyvgl orngf chevgl.
Reebef fubhyq arire cnff fvyragyl.
Hayrff rkcyvpvgyl fvyraprq.
Va gur snpr bs nzovthvgl, ershfr gur grzcgngvba gb thrff.
Gurer fubhyq or bar-- naq cersrenoyl bayl bar --boivbhf jnl gb qb vg.
Nygubhtu gung jnl znl abg or boivbhf ng svefg hayrff lbh'er Qhgpu.
Abj vf orggre guna arire.
Nygubhtu arire vf bsgra orggre guna *evtug* abj.
Vs gur vzcyrzragngvba vf uneq gb rkcynva, vg'f n onq vqrn.
Vs gur vzcyrzragngvba vf rnfl gb rkcynva, vg znl or n tbbq vqrn.
Anzrfcnprf ner bar ubaxvat terng vqrn -- yrg'f qb zber bs gubfr!"""

d = {}
for c in (65, 97):
    for i in range(26):
        d[chr(i + c)] = chr((i + 13) % 26 + c)

print(
    GoogleTranslator(source='auto', target='cs').translate("".join([d.get(c, c) for c in s]))
    )
# Out:
# Overwriting this.py

# %%
# !python this.py
# Out:
# For import only

# %%
# opětovný přesun aktuální cesty na začátek, aby se našel a načetl náš upravený modul
sys.path = [sys.path[-1], *sys.path[0:-1]]
print(sys.path)

import this
this = reload(this)
# Out:
# ['/content', '/env/python', '/usr/lib/python311.zip', '/usr/lib/python3.11', '/usr/lib/python3.11/lib-dynload', '', '/usr/local/lib/python3.11/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.11/dist-packages/IPython/extensions', '/root/.ipython']
# Zen Pythonu, Tim Peters
#
# Krásná je lepší než ošklivá.
# Explicitní je lepší než implicitní.
# Jednoduché je lepší než složité.
# Komplex je lepší než komplikované.
# Byt je lepší než vnořený.
# Řídká je lepší než hustá.
# Počty čitelnosti.
# Zvláštní případy nejsou dostatečně zvláštní, aby porušily pravidla.
# Ačkoli praktičnost bije čistotu.
# Chyby by nikdy neměly procházet tiše.
# Pokud není výslovně umlčena.
# Tváří v tvář nejednoznačnosti odmítněte pokušení uhodnout.
# Měl by existovat jeden-a nejlépe jen jeden-zřejmý způsob, jak to udělat.
# Ačkoli tento způsob nemusí být zpočátku zřejmý, pokud nejste nizozemští.
# Nyní je lepší než nikdy.
# Ačkoli nikdy není často lepší než * správně *.
# Pokud je implementace obtížně vysvětleno, je to špatný nápad.
# Pokud je implementace snadno vysvětlitelná, může to být dobrý nápad.
# Jmenné prostory jsou jeden troubící skvělý nápad - udělejme z nich více!

# %% [markdown]
# # Balíčky

# %% [markdown]
# ![Package-Flat-icon.png](data:image/png;base64,...)

# %% [markdown]
# Pro rozsáhlejší projekty je vhodné nemít všechny objekty v rámci jednoho modulu - potřebujeme nějaký další level uspořádání. Pro ten slouží balíčky.
#
# Balíčky v pythonu vytvoříme velmi snadno, **každý adresář obsahující soubor `__init__.py` je balíček** a všechny další `*.py` soubory jsou moduly v rámci balíčku.
#
# Poznámka: balíček může existovat i bez `__init__.py`, to je pak **namespace** packages viz. [přednáška](http://vyuka.ookami.cz/materialy/python/modules/_modules.xml) nebo [StackOverflow](https://stackoverflow.com/questions/21819649/namespace-vs-regular-package)

# %%
# !apt-get -q install tree

# vytvoření struktury balíčku `pack`
# !mkdir pack 2&>1
# !touch pack/__init__.py
# !tree pack/
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 30 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (157 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 126213 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# pack/
# └── __init__.py
#
# 0 directories, 1 file

# %%
# %%writefile pack/first.py

def hello():
  print("Hello from first module!")
# Out:
# Writing pack/first.py

# %%
# %%writefile pack/second.py

def hello():
  print("Hello from second module!")
# Out:
# Writing pack/second.py

# %%
# !tree pack/
# Out:
# pack/
# ├── first.py
# ├── __init__.py
# └── second.py
#
# 0 directories, 3 files

# %% [markdown]
# Náš nový balíček pak používáme očekávaným způsobem:

# %%
from pack import first
from pack.second import hello as h2
first.hello()
h2()
# Out:
# Hello from first module!
# Hello from second module!

# %%
import pack
help(pack)
dir(pack)
# Out:
# Help on package pack:
#
# NAME
#     pack
#
# PACKAGE CONTENTS
#     first
#     second
#
# FILE
#     /content/pack/__init__.py
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'first',
#  'second']

# %%
help(first)
# Out:
# Help on module pack.first in pack:
#
# NAME
#     pack.first
#
# FUNCTIONS
#     hello()
#
# FILE
#     /content/pack/first.py

# %% [markdown]
# Pokud `__init__.py` bude obsahovat nějaký kód, spustí se při importu balíčku.

# %%
# %%writefile pack/__init__.py

print("Importing module.")
# Out:
# Overwriting pack/__init__.py

# %%
import pack
from importlib import reload
pack = reload(pack)
first.hello()
# Out:
# Importing module.
# Hello from first module!

# %% [markdown]
# Pokud do balíčku přidáme soubor `__main__.py`, budeme moci spouštět balíček z příkazové řádky

# %%
# %%writefile pack/__main__.py
from pack import first

print("Running module.")

first.hello()
# Out:
# Writing pack/__main__.py

# %%
# !tree pack/
# Out:
# pack/
# ├── first.py
# ├── __init__.py
# ├── __main__.py
# ├── __pycache__
# │   ├── first.cpython-311.pyc
# │   ├── __init__.cpython-311.pyc
# │   └── second.cpython-311.pyc
# └── second.py
#
# 1 directory, 7 files

# %%
# !rm pack/__main__.py
# !python -m pack
# Out:
# Importing module.
# Running module.
# Hello from first module!

# %% [markdown]
# Další informace o modulech, balíčcích, binárních balíčcích, setuptools, PyPI atd. najdete v [podkladech](https://naucse.python.cz/lessons/intro/distribution/) z MI-PYT.

# %% [markdown]
# # Importování modulů, balíčků a objektů z nich
#
# Importy by měly být na začátku modulu, hned po docstringu. Obvykle se dělí na 3 kategorie (built-in, nainstalované knihovny, vlastní součásti aplikace), které se pro přehlednost oddělují prázným řádkem. Dobrým zvykem je řadit importované moduly v kategorii podle názvu abecedně, aby je bylo snadné dohledat.
#
# Příklad:

# %%
# %cd /content/
# !mkdir -p semestralka/model
# !mkdir -p semestralka/gui/game
# !touch semestralka/gui/__init__.py && touch semestralka/gui/game/__init__.py && touch semestralka/model/__init__.py && touch semestralka/gui/menu.py && touch semestralka/gui/scoreboard.py && touch semestralka/gui/game/dungeon.py
# !touch semestralka/model/score.py && touch semestralka/model/gamestate.py
# !tree semestralka/
# Out:
# /content
# semestralka/
# ├── gui
# │   ├── game
# │   │   ├── dungeon.py
# │   │   └── __init__.py
# │   ├── __init__.py
# │   ├── menu.py
# │   └── scoreboard.py
# └── model
#     ├── gamestate.py
#     ├── __init__.py
#     └── score.py
#
# 3 directories, 8 files

# %%
# %cd /semestralka
#%cd ..
#!rm -rf semestralka
# Out:
# [Errno 2] No such file or directory: '/semestralka'
# /content/semestralka

# %%
# %%writefile model/score.py
class ScoreReader:
    def read(self):
        return {'Winner': 42 , 'Looser': 0}
# Out:
# Overwriting model/score.py

# %%
# %%writefile gui/game/dungeon.py
def burn_all():
    print('Fire!')

if __name__ == '__main__':
  burn_all()
# Out:
# Overwriting gui/game/dungeon.py

# %%
#!cat gui/game/dungeon.py
# absolutní importy
from gui import menu
from gui import scoreboard as sb
#from gui.game.dungeon import burn_all
from gui.game.dungeon import burn_all
from model.score import ScoreReader

sr = ScoreReader().read()
print(sr)

burn_all()
# Out:
# {'Winner': 42, 'Looser': 0}
# Fire!

# %% [markdown]
# Existují i relativní importy, kde `.` představuje aktuální adresář, `..` skok do nadřazeného adresáře. Ale doporučuji je nepoužívat, neboť přinášejí vícero úskalí, jsou hůře čitelné, nemusí vám s nimi fungovat pytest (spouští v kontextu modulu s testy, ne samotného modulu s implementaci a cesty tak nemusí sedět).
#
# Závěr: **Používejte absolutní cesty v importech.**

# %%
# %%writefile gui/game/dungeon.py
from .. import menu
def burn_all():
    print('Fire!')

if __name__ == '__main__':
  burn_all()
  print(help(menu))
# Out:
# Overwriting gui/game/dungeon.py

# %%
# !python gui/game/dungeon.py
# !echo "---------------------------------------"
# !python -m gui.game.dungeon
# Out:
# Traceback (most recent call last):
#   File "/content/semestralka/gui/game/dungeon.py", line 1, in <module>
#     from .. import menu
# ImportError: attempted relative import with no known parent package
# ---------------------------------------
# Fire!
# Help on module gui.menu in gui:
#
# E
#     gui.menu
#
# E
#     /content/semestralka/gui/menu.py
#
#
# None
